# %%
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_23296\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
#See the data that's been imported

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up data

# %%
#Only want CAN races, 50k or 50 miles

# %%
#step 1, show 50 miles or 50k or 50 mi

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461089                  50km                          6           4:19:56 h
# 7461090                  50km                          6           4:28:57 h
# 7461091                  50km                          6           4:46:39 h
# 7461092                  50km                          6           4:47:39 h
# 7461093                  50km                          6           5:58:16 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461089                *QLD             AUS                 1956.0
# 7461090                *QLD             AUS                 1954.0
# 7461091                *QLD             AUS                 1951.0
# 7461092                *QLD             AUS                 1939.0
# 7461093                *QLD             AUS                 1938.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461089              F                  W35               11541.0     1046326
# 7461090              M                  M40               11154.0     1070007
# 7461091              M                  M40               10466.0      345672
# 7461092              M                  M55               10429.0     1082443
# 7461093              F                  W55                8374.0     1082581
#
# [1522609 rows x 13 columns]

# %%
#combined 50km with 50 mi

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461181                  50mi                         92          11:59:37 h
# 7461182                  50mi                         92          12:01:41 h
# 7461183                  50mi                         92          12:03:26 h
# 7461184                  50mi                         92          12:03:26 h
# 7461185                  50mi                         92          12:05:59 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461181                 NaN             USA                 1941.0
# 7461182                 NaN             USA                 1932.0
# 7461183                 NaN             USA                 1934.0
# 7461184                 NaN             USA                 1951.0
# 7461185                 NaN             USA                 1947.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461181              M                  M50                6709.0     1045603
# 7461182              M                  M60                6690.0     1070463
# 7461183              F                  W60                6674.0      416139
# 7461184              F                  W40                6674.0     1098098
# 7461185              F                  W45                6650.0     1626367
#
# [1874790 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...                                          ...                   ...
# 2762404               Bison Ultra-Trail 50 (POL)                  50km
# 2762405               Bison Ultra-Trail 50 (POL)                  50km
# 2762406               Bison Ultra-Trail 50 (POL)                  50km
# 2762407               Bison Ultra-Trail 50 (POL)                  50km
# 2762408               Bison Ultra-Trail 50 (POL)                  50km
#
#          Event number of finishers Athlete performance          Athlete club  \
# 2538571                         38           7:34:19 h                   日本隊
# 2538572                         38           7:43:50 h                   NaN
# 2538573                         38           8:04:40 h                   NaN
# 2538574                         38           8:30:49 h             台灣大腳ㄚ長跑協會
# 2538575                         38           8:34:47 h                   NaN
# ...                            ...                 ...                   ...
# 2762404                        271           7:36:25 h  AKS Polonia Warszawa
# 2762405                        271           7:36:27 h             *Warszawa
# 2762406                        271           7:44:18 h      Outdoor Training
# 2762407                        271           8:04:50 h      PH Bysewo Gdańsk
# 2762408                        271           8:11:43 h    *Nowe Aleksandrowo
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
# ...                 ...                    ...            ...
# 2762404             POL                 1981.0              F
# 2762405             POL                 1970.0              F
# 2762406             POL                 1993.0              F
# 2762407             POL                 1976.0              M
# 2762408             POL                 1961.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627       53107
# 2538572                  M45                10.409        8785
# 2538573                  M40                 9.962        4502
# 2538574                  W50                 9.452       63964
# 2538575                  M55                 9.379        4485
# ...                      ...                   ...         ...
# 2762404                  W35                 6.573      860743
# 2762405                  W45                 6.572      860744
# 2762406                  W23                 6.461      860745
# 2762407                  M40                 6.188      798409
# 2762408                  M55                 6.101      860746
#
# [63489 rows x 13 columns]

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CAN']
# Out:
#          Year of event Event dates  \
# 25299             2018  10.03.2018
# 25300             2018  10.03.2018
# 25301             2018  10.03.2018
# 25302             2018  10.03.2018
# 25303             2018  10.03.2018
# ...                ...         ...
# 7450076           1995  16.04.1995
# 7450077           1995  16.04.1995
# 7450078           1995  16.04.1995
# 7450079           1995  16.04.1995
# 7450080           1995  16.04.1995
#
#                                             Event name Event distance/length  \
# 25299                        Dirty Duo Trail Run (CAN)                  50km
# 25300                        Dirty Duo Trail Run (CAN)                  50km
# 25301                        Dirty Duo Trail Run (CAN)                  50km
# 25302                        Dirty Duo Trail Run (CAN)                  50km
# 25303                        Dirty Duo Trail Run (CAN)                  50km
# ...                                                ...                   ...
# 7450076  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450077  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450078  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450079  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450080  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 25299                           34           4:58:08 h          NaN
# 25300                           34           5:16:44 h          NaN
# 25301                           34           5:22:32 h          NaN
# 25302                           34           5:40:38 h          NaN
# 25303                           34           5:49:23 h          NaN
# ...                            ...                 ...          ...
# 7450076                          5           3:40:31 h          NaN
# 7450077                          5           3:46:22 h          NaN
# 7450078                          5           4:06:20 h          NaN
# 7450079                          5           4:15:02 h          NaN
# 7450080                          5           4:48:38 h          NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 25299               IND                 1980.0              M
# 25300               CAN                 1984.0              M
# 25301               CAN                 1999.0              M
# 25302               CAN                 1986.0              M
# 25303               USA                 1994.0              F
# ...                 ...                    ...            ...
# 7450076             CAN                 1966.0              M
# 7450077             USA                 1958.0              M
# 7450078             CAN                 1959.0              F
# 7450079             CAN                    NaN              M
# 7450080             CAN                    NaN              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 25299                    M35                10.063       23912
# 25300                    M23                 9.472       23913
# 25301                   MU23                 9.301       23914
# 25302                    M23                 8.807       23915
# 25303                    W23                 8.587       23916
# ...                      ...                   ...         ...
# 7450076                  M23               13604.0     1001224
# 7450077                  M35               13253.0     1105362
# 7450078                  W35               12179.0     1052424
# 7450079                  NaN               11763.0     1640552
# 7450080                  NaN               10394.0     1640553
#
# [92628 rows x 13 columns]

# %%
#Combined all filters to get UM races in the US and that took place in 2020

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CAN')]
# Out:
#          Year of event Event dates                              Event name  \
# 2553771           2020  19.01.2020   Winter River Valley Revenge 50k (CAN)
# 2553772           2020  19.01.2020   Winter River Valley Revenge 50k (CAN)
# 2553773           2020  19.01.2020   Winter River Valley Revenge 50k (CAN)
# 2553774           2020  19.01.2020   Winter River Valley Revenge 50k (CAN)
# 2553775           2020  19.01.2020   Winter River Valley Revenge 50k (CAN)
# ...                ...         ...                                     ...
# 2749993           2020  17.10.2020  Relentless at the Ark Trail Race (CAN)
# 2749994           2020  17.10.2020  Relentless at the Ark Trail Race (CAN)
# 2749995           2020  17.10.2020  Relentless at the Ark Trail Race (CAN)
# 2749996           2020  17.10.2020  Relentless at the Ark Trail Race (CAN)
# 2749997           2020  17.10.2020  Relentless at the Ark Trail Race (CAN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553771                  50km                         23           7:19:24 h
# 2553772                  50km                         23           7:30:18 h
# 2553773                  50km                         23           7:43:53 h
# 2553774                  50km                         23           7:43:53 h
# 2553775                  50km                         23           7:47:30 h
# ...                       ...                        ...                 ...
# 2749993                  50km                         18           7:54:15 h
# 2749994                  50km                         18           9:55:15 h
# 2749995                  50km                         18           9:55:19 h
# 2749996                  50km                         18           9:55:21 h
# 2749997                  50km                         18           9:55:27 h
#
#               Athlete club Athlete country  Athlete year of birth  \
# 2553771      *Edmonton, AB             CAN                    NaN
# 2553772      *Edmonton, AB             CAN                 1981.0
# 2553773  *Spruce Grove, AB             CAN                 1984.0
# 2553774      *Edmonton, AB             CAN                 1984.0
# 2553775      *Edmonton, AB             CAN                    NaN
# ...                    ...             ...                    ...
# 2749993                NaN             CAN                    NaN
# 2749994                NaN             CAN                 2001.0
# 2749995                NaN             CAN                 1978.0
# 2749996                NaN             CAN                 1977.0
# 2749997                NaN             CAN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2553771              M                  NaN                 6.827      813311
# 2553772              M                  M35                 6.662      114983
# 2553773              M                  M35                 6.467      813312
# 2553774              M                  M35                 6.467      692475
# 2553775              M                  NaN                 6.417      813313
# ...                ...                  ...                   ...         ...
# 2749993              M                  NaN                 6.326      857987
# 2749994              F                 WU23                  5.04      833662
# 2749995              F                  W40                 5.039      326034
# 2749996              M                  M40                 5.039      326033
# 2749997              M                  NaN                 5.038      857988
#
# [247 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CAN')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates                             Event name  \
# 2553771           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553772           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553773           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553774           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553775           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553776           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553777           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553778           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553779           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
# 2553780           2020  19.01.2020  Winter River Valley Revenge 50k (CAN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553771                  50km                         23           7:19:24 h
# 2553772                  50km                         23           7:30:18 h
# 2553773                  50km                         23           7:43:53 h
# 2553774                  50km                         23           7:43:53 h
# 2553775                  50km                         23           7:47:30 h
# 2553776                  50km                         23           7:48:16 h
# 2553777                  50km                         23           8:18:46 h
# 2553778                  50km                         23           8:29:28 h
# 2553779                  50km                         23           8:29:30 h
# 2553780                  50km                         23           8:54:51 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 2553771       *Edmonton, AB             CAN                    NaN
# 2553772       *Edmonton, AB             CAN                 1981.0
# 2553773   *Spruce Grove, AB             CAN                 1984.0
# 2553774       *Edmonton, AB             CAN                 1984.0
# 2553775       *Edmonton, AB             CAN                    NaN
# 2553776        *Calgary, AB             CAN                 1987.0
# 2553777  *Sherwood Park, AB             CAN                    NaN
# 2553778       *Edmonton, AB             CAN                 1982.0
# 2553779   *Spruce Grove, AB             CAN                    NaN
# 2553780  *Beaver County, AB             CAN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2553771              M                  NaN                 6.827      813311
# 2553772              M                  M35                 6.662      114983
# 2553773              M                  M35                 6.467      813312
# 2553774              M                  M35                 6.467      692475
# 2553775              M                  NaN                 6.417      813313
# 2553776              M                  M23                 6.407       87092
# 2553777              M                  NaN                 6.015      813314
# 2553778              F                  W35                 5.889      339980
# 2553779              M                  NaN                 5.888      813315
# 2553780              F                  NaN                 5.609      813316

# %%
df2.shape
# Out:
# (247, 13)

# %%
#remove (CAN) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2553771     Winter River Valley Revenge 50k
# 2553772     Winter River Valley Revenge 50k
# 2553773     Winter River Valley Revenge 50k
# 2553774     Winter River Valley Revenge 50k
# 2553775     Winter River Valley Revenge 50k
#                          ...
# 2749993    Relentless at the Ark Trail Race
# 2749994    Relentless at the Ark Trail Race
# 2749995    Relentless at the Ark Trail Race
# 2749996    Relentless at the Ark Trail Race
# 2749997    Relentless at the Ark Trail Race
# Name: Event name, Length: 247, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_23296\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                        Event name  \
# 2553771           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553772           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553773           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553774           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553775           2020  19.01.2020  Winter River Valley Revenge 50k
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553771                  50km                         23           7:19:24 h
# 2553772                  50km                         23           7:30:18 h
# 2553773                  50km                         23           7:43:53 h
# 2553774                  50km                         23           7:43:53 h
# 2553775                  50km                         23           7:47:30 h
#
#               Athlete club Athlete country  Athlete year of birth  \
# 2553771      *Edmonton, AB             CAN                    NaN
# 2553772      *Edmonton, AB             CAN                 1981.0
# 2553773  *Spruce Grove, AB             CAN                 1984.0
# 2553774      *Edmonton, AB             CAN                 1984.0
# 2553775      *Edmonton, AB             CAN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2553771              M                  NaN                 6.827      813311
# 2553772              M                  M35                 6.662      114983
# 2553773              M                  M35                 6.467      813312
# 2553774              M                  M35                 6.467      692475
# 2553775              M                  NaN                 6.417      813313

# %%
#clean up athlete age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_23296\3897931444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
# remove h from athlete performance

# %%
df2['Athlete performance'].str.split('(').str.get(0)
# Out:
# 2553771    7:19:24 h
# 2553772    7:30:18 h
# 2553773    7:43:53 h
# 2553774    7:43:53 h
# 2553775    7:47:30 h
#              ...
# 2749993    7:54:15 h
# 2749994    9:55:15 h
# 2749995    9:55:19 h
# 2749996    9:55:21 h
# 2749997    9:55:27 h
# Name: Athlete performance, Length: 247, dtype: object

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_23296\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                        Event name  \
# 2553771           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553772           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553773           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553774           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553775           2020  19.01.2020  Winter River Valley Revenge 50k
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553771                  50km                         23             7:19:24
# 2553772                  50km                         23             7:30:18
# 2553773                  50km                         23             7:43:53
# 2553774                  50km                         23             7:43:53
# 2553775                  50km                         23             7:47:30
#
#               Athlete club Athlete country  Athlete year of birth  \
# 2553771      *Edmonton, AB             CAN                    NaN
# 2553772      *Edmonton, AB             CAN                 1981.0
# 2553773  *Spruce Grove, AB             CAN                 1984.0
# 2553774      *Edmonton, AB             CAN                 1984.0
# 2553775      *Edmonton, AB             CAN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 2553771              M                  NaN                 6.827      813311
# 2553772              M                  M35                 6.662      114983
# 2553773              M                  M35                 6.467      813312
# 2553774              M                  M35                 6.467      692475
# 2553775              M                  NaN                 6.417      813313
#
#          athlete_age
# 2553771          NaN
# 2553772         39.0
# 2553773         36.0
# 2553774         36.0
# 2553775          NaN

# %%
# remove columns that you don't want from data, Athlete Club, Athlete Country, Athlete YOB, Athlete Age Category

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates                        Event name  \
# 2553771           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553772           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553773           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553774           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553775           2020  19.01.2020  Winter River Valley Revenge 50k
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553771                  50km                         23             7:19:24
# 2553772                  50km                         23             7:30:18
# 2553773                  50km                         23             7:43:53
# 2553774                  50km                         23             7:43:53
# 2553775                  50km                         23             7:47:30
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2553771              M                 6.827      813311          NaN
# 2553772              M                 6.662      114983         39.0
# 2553773              M                 6.467      813312         36.0
# 2553774              M                 6.467      692475         36.0
# 2553775              M                 6.417      813313          NaN

# %%
# clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                 0
# Event dates                   0
# Event name                    0
# Event distance/length         0
# Event number of finishers     0
# Athlete performance           0
# Athlete gender                0
# Athlete average speed         0
# Athlete ID                    0
# athlete_age                  36
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates                         Event name  \
# 2553771           2020  19.01.2020   Winter River Valley Revenge 50k
# 2553775           2020  19.01.2020   Winter River Valley Revenge 50k
# 2553777           2020  19.01.2020   Winter River Valley Revenge 50k
# 2553779           2020  19.01.2020   Winter River Valley Revenge 50k
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2553771              M                 6.827      813311          NaN
# 2553775              M                 6.417      813313          NaN
# 2553777              M                 6.015      813314          NaN
# 2553779              M                 5.888      813315          NaN
# 2553780              F                 5.609      813316          NaN
# 2553784              M                 5.504       65362          NaN
# 2553788              F                 5.202      813319          NaN
# 2553792              M                 4.966      813321          NaN
# 2553793              M                 4.865      813322          NaN
# 2580377              M                 7.556      818840          NaN
# 2580379              M                 7.472      818841          NaN
# 2580381              M                 6.738      818842          NaN
# 2580388              F                 5.071      645353          NaN
# 2599669              M                  8.82       19745          NaN
# 2599670              M                 8.291      481111          NaN
# 2599682              M                 6.328      822639          NaN
# 2739869              M                11.047      855589          NaN
# 2739871              M                10.793      855590          NaN
# 2739872              M                10.765      855591          NaN
# 2739874              M                10.442      855592          NaN
# 2739879              M                 9.629      855593          NaN
# 2739898              M                 6.925      855595          NaN
# 2739902              F                 6.233      855596          NaN
# 2739906              M                 6.138      855597          NaN
# 2739908              M                 5.915      855598          NaN
# 2739909              F                 5.606      402084          NaN
# 2739915              M                 5.375      855600          NaN
# 2749980              M                10.532      314391          NaN
# 2749981              M                 9.707      857982          NaN
# 2749988              M                 7.412       97600          NaN
# 2749989              M                 7.375      857984          NaN
# 2749990              F                 7.226      857985          NaN
# 2749991              M                 7.225      857986          NaN
# 2749992              M                 6.877      314397          NaN
# 2749993              M                 6.326      857987          NaN
# 2749997              M                 5.038      857988          NaN

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (211, 10)

# %%
#check for dupes

# %%
df2[df2.duplicates() == True]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23296\3239160751.py in ?()
# ----> 1 df2[df2.duplicates() == True]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
#reset index

# %%
df2.reset_index(drop = True)

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                        Event name  \
# 2553772           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553773           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553774           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553776           2020  19.01.2020  Winter River Valley Revenge 50k
# 2553778           2020  19.01.2020  Winter River Valley Revenge 50k
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2553772                  50km                         23             7:30:18
# 2553773                  50km                         23             7:43:53
# 2553774                  50km                         23             7:43:53
# 2553776                  50km                         23             7:48:16
# 2553778                  50km                         23             8:29:28
#
#         Athlete gender  Athlete average speed  Athlete ID  athlete_age
# 2553772              M                  6.662      114983           39
# 2553773              M                  6.467      813312           36
# 2553774              M                  6.467      692475           36
# 2553776              M                  6.407       87092           33
# 2553778              F                  5.889      339980           38

# %%
#rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#athlete_age                    int32
#dtype: object

# %%
df2 = df2.rename(columns = {'Year of event': 'year' ,
                            'Event dates': 'race_day',
                            'Event name': 'race_name',
                            'Event distance/length': 'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id',
                           })

# %%
df2.head()
# Out:
#          year    race_day                         race_name race_length  \
# 2553772  2020  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553773  2020  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553774  2020  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553776  2020  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553778  2020  19.01.2020  Winter River Valley Revenge 50k         50km
#
#          race_number_of_finishers athlete_performance athlete_gender  \
# 2553772                        23             7:30:18              M
# 2553773                        23             7:43:53              M
# 2553774                        23             7:43:53              M
# 2553776                        23             7:48:16              M
# 2553778                        23             8:29:28              F
#
#          athlete_average_speed  athlete_id  athlete_age
# 2553772                  6.662      114983           39
# 2553773                  6.467      813312           36
# 2553774                  6.467      692475           36
# 2553776                  6.407       87092           33
# 2553778                  5.889      339980           38

# %%
#reorder columns

# %%
df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance', 'athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day                         race_name race_length  \
# 2553772  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553773  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553774  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553776  19.01.2020  Winter River Valley Revenge 50k         50km
# 2553778  19.01.2020  Winter River Valley Revenge 50k         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2553772                        23      114983              M           39
# 2553773                        23      813312              M           36
# 2553774                        23      692475              M           36
# 2553776                        23       87092              M           33
# 2553778                        23      339980              F           38
#
#         athlete_performance  athlete_average_speed
# 2553772             7:30:18                  6.662
# 2553773             7:43:53                  6.467
# 2553774             7:43:53                  6.467
# 2553776             7:48:16                  6.407
# 2553778             8:29:28                  5.889

# %%
#find 2 races that he ran in 2020 - Sarasota / Everglades

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
# Empty DataFrame
# Columns: [race_day, race_name, race_length, race_number_of_finishers, athlete_id, athlete_gender, athlete_age, athlete_performance, athlete_average_speed]
# Index: []

# %%
#222509 which is the athlete ID

# %%
df3[df3['athlete_id'] == 222509]
# Out:
# Empty DataFrame
# Columns: [race_day, race_name, race_length, race_number_of_finishers, athlete_id, athlete_gender, athlete_age, athlete_performance, athlete_average_speed]
# Index: []

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quartz' , linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x= 'athlete_age', y='athlete_average_speed', hue = 'athlete_gender')

# %%
#questions trying to find from data

# %%
#difference in speed for the 50km, 50mil male to female

# %%
df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 6.972435
#              M                 7.559432
# 50mi         F                 6.164400
#              M                 6.722800
# Name: athlete_average_speed, dtype: float64

# %%
#what age groups are the best in the 50mi Race (20 + races min)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count>19')
# Out:
# Empty DataFrame
# Columns: [mean, count]
# Index: []

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count>19')
# Out:
# Empty DataFrame
# Columns: [mean, count]
# Index: []

# %%
#what age groups are the worst in the 50mile Race (20 + races min) (show 15)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count>9')
# Out:
# Empty DataFrame
# Columns: [mean, count]
# Index: []

# %%
# Seasons for the data
# spring 3-5
# summer 6-8
# fall 9-11
# winter 11-2
#split between two decimals

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3.head(25)
# Out:
#            race_day                         race_name race_length  \
# 2553772  19.01.2020  Winter River Valley Revenge 50k         50km
# 2